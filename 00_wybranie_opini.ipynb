# %% [markdown]
# # Notebook 0: Wybranie opini z gry Final Fantasy XIII
#
# **Autor:** Michał Bogdański
#
# **Opis:** Projekt realizuje analizę sentymentu recenzji steam. Porównujemy podejście klasyczne (TF-IDF + SVM) z podejściem opartym na Transformerach (HerBERT).
#
# **Źródło danych:** Zbiór `Steam Reviews` z kaggle.com – podział na oceny pozytywny i negatywne.
#
# W tym notebooku:
# 1. Ładujemy dane
# 2. Tworzymy nowy plik csv z opiniami o grze Final Fantasy XIII

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ## 2. Pobranie i załadowanie danych
#
# Korzystamy ze zbioru `Steam Reviews` dostępnego na kaggle.com. Zbiór zawiera recenzje w języku angielskim gier na steam (pozytywne/negatywne).

# %%
df = pd.read_csv("steam_reviews.csv")
df = df.dropna(subset=['review_text', 'review_score'])
print(f"Liczba rekordów: {len(df)}")
print(f"Kolumny: {list(df.columns)}")
df.head()
# Out:
# Liczba rekordów: 6409801
# Kolumny: ['app_id', 'app_name', 'review_text', 'review_score', 'review_votes']
#    app_id        app_name                                        review_text  \
# 0      10  Counter-Strike                                    Ruined my life.
# 1      10  Counter-Strike  This will be more of a ''my experience with th...
# 2      10  Counter-Strike                      This game saved my virginity.
# 3      10  Counter-Strike  • Do you like original games? • Do you like ga...
# 4      10  Counter-Strike           Easy to learn, hard to master.
#
#    review_score  review_votes
# 0             1             0
# 1             1             1
# 2             1             0
# 3             1             0
# 4             1             1

# %%
df[df['app_name'] == 'FINAL FANTASY XIII']
# Out:
#          app_id            app_name  \
# 3663649  292120  FINAL FANTASY XIII
# 3663650  292120  FINAL FANTASY XIII
# 3663651  292120  FINAL FANTASY XIII
# 3663652  292120  FINAL FANTASY XIII
# 3663653  292120  FINAL FANTASY XIII
# ...         ...                 ...
# 3667545  292120  FINAL FANTASY XIII
# 3667546  292120  FINAL FANTASY XIII
# 3667547  292120  FINAL FANTASY XIII
# 3667548  292120  FINAL FANTASY XIII
# 3667549  292120  FINAL FANTASY XIII
#
#                                                review_text  review_score  \
# 3663649  This game has a tremendous polarizing effect o...             1
# 3663650  From what I have gathered, this game is somewh...             1
# 3663651  It's really hard to talk about this game. I've...            -1
# 3663652   ok, now i finally beat this game, time for a ...             1
# 3663653   This review is spoiler-free.   First things f...             1
# ...                                                    ...           ...
# ...

# %%
df[df['app_name'] == 'FINAL FANTASY XIII'][['review_text', 'review_score']].to_csv('final_fantasy_XIII.csv', index=False)
